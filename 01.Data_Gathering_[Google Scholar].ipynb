# %% [markdown]
# # Data Gathering

# %%
# We'll make use of DBLP dataset namely DBLP-Citation-network V12 from https://www.aminer.org/citation

# Steps:
# 1. Unzip dblp.v12.7z -> dblp.v12.json 
# 2. Convert json array content into one item per line
# jq -cn --stream "fromstream(1|truncate_stream(inputs))" dblp.v12.json > dblp.v12.jsonl
# 3. Split jsonl file into smaller chunks
# split -l 10000 dblp.v12.jsonl
# 4. Loop through chunk files and read data into dataframe

# %%
# import required dependencies
import json
import glob
import ast
import re

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.float_format', lambda x: '%.2f' % x)
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
CHUNK_DATA_PATH = "data/dblp/chunks"
CHUNK_DATA_PATH
# Out:
# 'data/dblp/chunks'

# %%
chunk_files = glob.glob(f"{CHUNK_DATA_PATH}/*")
len(chunk_files)
# Out:
# 490

# %%
chunk_files[:10]
# Out:
# ['data/dblp/chunks/pc',
#  'data/dblp/chunks/sl',
#  'data/dblp/chunks/pd',
#  'data/dblp/chunks/sk',
#  'data/dblp/chunks/sb',
#  'data/dblp/chunks/pm',
#  'data/dblp/chunks/se',
#  'data/dblp/chunks/pj',
#  'data/dblp/chunks/px',
#  'data/dblp/chunks/sp']

# %%
sample_df = None

with open('data/dblp/chunks/pc') as f:
    sample_df = pd.DataFrame(json.loads(line) for line in f)

sample_df
# Out:
#               id                                            authors  \
# 0     2873507692  [{'name': 'Ioannis Delis', 'org': 'Department ...
# 1     2873533962  [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...
# 2     2873535434  [{'name': 'Li Cheng', 'org': 'School of Electr...
# 3     2873541924  [{'name': 'Dov Danon', 'id': 2230089554}, {'na...
# 4     2873550248  [{'name': 'Qijing Yu', 'org': 'Psychology Depa...
# ...          ...                                                ...
# 9995  2884790315  [{'name': 'Fabio G. Guerrero', 'org': 'School ...
# 9996  2884790510  [{'name': 'Manish Sharma', 'org': 'Department ...
# 9997  2884790907  [{'name': 'Ryan Aldrich', 'id': 2884488651}, {...
# 9998  2884791133  [{'name': 'Xiaoping Sun', 'org': 'Laboratory o...
# 9999  2884791473  [{'name': 'Federica Sciacchitano', 'id': 26455...
#
#                                                   title  year  n_citation  \
# 0     Characterization of whole-body muscle activity...  2018           0
# 1     The effect of codebook design on the BER perfo...  2018           0
# 2     An Optimized Infrared Detection Strategy for D...  2018           0
# 3             Unsupervised Natural Image Patch Learning  2018           0
# 4     Age-associated increase in mnemonic strategy u...  2018           2
# ...                                                 ...   ...         ...
# 9995  An interactive approach for illustrating a pro...  2018           0
# 9996  An automated diagnosis of depression using thr...  2018          18
# 9997  Low-Cost Radar for Object Tracking in Autonomo...  2018           3
# 9998  Summarization of Scientific Paper Through Rein...  2018           6
# 9999            Sparse Bayesian Imaging of Solar Flares  2018           1
#
#      page_start page_end    doc_type  \
# 0            44           Conference
# 1             1        4  Conference
# 2         38137    38146     Journal
# 3                         Repository
# 4           162      169     Journal
# ...         ...      ...         ...
# 9995       2282     2293     Journal
# 9996        508      520     Journal
# 9997          1        5  Conference
# 9998      40611    40625     Journal
# 9999                      Repository
#
#                                               publisher volume issue  \
# 0                                                   ACM
# 1                                                  IEEE
# 2     Institute of Electrical and Electronics Engine...      6
# 3
# 4                                        Academic Press    181
# ...                                                 ...    ...   ...
# 9995                             John Wiley & Sons, Ltd     26     6
# 9996                                        Elsevier BV     52
# 9997                                               IEEE
# 9998  Institute of Electrical and Electronics Engine...      6
# 9999
#
#                                    doi  \
# 0              10.1145/3200947.3201006
# 1             10.1109/siu.2018.8404779
# 2          10.1109/access.2018.2854221
# 3
# 4     10.1016/j.neuroimage.2018.07.008
# ...                                ...
# 9995                 10.1002/cae.22041
# 9996      10.1016/j.cogsys.2018.07.010
# 9997    10.1109/vtcspring.2018.8417751
# 9998       10.1109/access.2018.2856530
# 9999
#
#                                              references  \
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995  [1995875735, 1998324813, 2024400985, 203890527...
# 9996  [1596717185, 2027927824, 2087347434, 209903329...
# 9997                                                NaN
# 9998  [850029481, 1525595230, 1972028996, 1972719750...
# 9999  [1976709621, 1996287810, 2039091494, 204758608...
#
#                                        indexed_abstract  \
# 0     {'IndexLength': 182, 'InvertedIndex': {'role.'...
# 1     {'IndexLength': 159, 'InvertedIndex': {'been':...
# 2     {'IndexLength': 195, 'InvertedIndex': {'been':...
# 3     {'IndexLength': 171, 'InvertedIndex': {'Clearl...
# 4     {'IndexLength': 219, 'InvertedIndex': {'(PFC),...
# ...                                                 ...
# 9995                                                NaN
# 9996  {'IndexLength': 279, 'InvertedIndex': {'optima...
# 9997  {'IndexLength': 168, 'InvertedIndex': {'distor...
# 9998  {'IndexLength': 255, 'InvertedIndex': {'Top-k'...
# 9999  {'IndexLength': 98, 'InvertedIndex': {'forming...
#
#                                                     fos  \
# 0     [{'name': 'Muscle activity', 'w': 0}, {'name':...
# 1     [{'name': 'Computer vision', 'w': 0.41825}, {'...
# 2     [{'name': 'Heat flux', 'w': 0.45008}, {'name':...
# 3     [{'name': 'Convergence (routing)', 'w': 0.4440...
# 4     [{'name': 'Semantic clustering', 'w': 0}, {'na...
# ...                                                 ...
# 9995  [{'name': 'Information theory', 'w': 0.49065},...
# 9996  [{'name': 'Orthogonal wavelet', 'w': 0.48532},...
# 9997  [{'name': 'Radar engineering details', 'w': 0....
# 9998  [{'name': 'Information system', 'w': 0.46617},...
# 9999  [{'name': 'Astronomy', 'w': 0.39551}, {'name':...
#
#                                                   venue
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'Computer Applications in Engineering ...
# 9996  {'raw': 'Cognitive Systems Research', 'id': 96...
# 9997  {'raw': 'Vehicular Technology Conference', 'id...
# 9998  {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 9999  {'raw': 'arXiv: Instrumentation and Methods fo...
#
# [10000 rows x 16 columns]

# %%
sample_df.filter(['id', 'title', 'authors', 'n_citation', 'year', 'doc_type', 'publisher', 'venue', 'references'])
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2884790315  An interactive approach for illustrating a pro...
# 9996  2884790510  An automated diagnosis of depression using thr...
# 9997  2884790907  Low-Cost Radar for Object Tracking in Autonomo...
# 9998  2884791133  Summarization of Scientific Paper Through Rein...
# 9999  2884791473            Sparse Bayesian Imaging of Solar Flares
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Fabio G. Guerrero', 'org': 'School ...           0  2018
# 9996  [{'name': 'Manish Sharma', 'org': 'Department ...          18  2018
# 9997  [{'name': 'Ryan Aldrich', 'id': 2884488651}, {...           3  2018
# 9998  [{'name': 'Xiaoping Sun', 'org': 'Laboratory o...           6  2018
# 9999  [{'name': 'Federica Sciacchitano', 'id': 26455...           1  2018
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995     Journal                             John Wiley & Sons, Ltd
# 9996     Journal                                        Elsevier BV
# 9997  Conference                                               IEEE
# 9998     Journal  Institute of Electrical and Electronics Engine...
# 9999  Repository
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'Computer Applications in Engineering ...
# 9996  {'raw': 'Cognitive Systems Research', 'id': 96...
# 9997  {'raw': 'Vehicular Technology Conference', 'id...
# 9998  {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 9999  {'raw': 'arXiv: Instrumentation and Methods fo...
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995  [1995875735, 1998324813, 2024400985, 203890527...
# 9996  [1596717185, 2027927824, 2087347434, 209903329...
# 9997                                                NaN
# 9998  [850029481, 1525595230, 1972028996, 1972719750...
# 9999  [1976709621, 1996287810, 2039091494, 204758608...
#
# [10000 rows x 9 columns]

# %%
# Create utility function to generate dataset and keep relevant columns

def get_df(files):
    """
    Generate dataframe for list
    of files
    """
    frames = []

    for file in tqdm(files):

        df = None
        with open(file) as f:
            df = pd.DataFrame(json.loads(line) for line in f).filter(
                [
                    'id', 
                    'title', 
                    'authors', 
                    'n_citation', 
                    'year',
                    'doc_type', 
                    'publisher',
                    'venue', 
                    'references'
                ]
            )

        frames.append(df)
        
    return pd.concat(frames)

# %%
df = get_df(chunk_files)
df
# Out:
#   0%|          | 0/490 [00:00<?, ?it/s]
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995                                                NaN
# 9996                                       [2401457073]
# 9997                                                NaN
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
# [4894081 rows x 9 columns]

# %%
# Replace NaN withe empty strings

df.fillna("", inplace=True)
df
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
# [4894081 rows x 9 columns]

# %%
def clean_title(title):
    """
    Clean title
    
    :param title: input title
    :return: clean title
    """
    charsToMatch = "[${}\r^]"
    
    words = title.split(" ")
    words = [
        word for word in words
            if not any([char in word for char in charsToMatch])
    ]
    return " ".join(words)

# %%
sample_title = '${\rm H}_{infty}$ Output Tracking Control of Discrete-Time Nonlinear Systems via Standard Neural Network Models'
sample_title
# Out:
# '${\rm H}_{infty}$ Output Tracking Control of Discrete-Time Nonlinear Systems via Standard Neural Network Models'

# %%
clean_title(sample_title)
# Out:
# 'Output Tracking Control of Discrete-Time Nonlinear Systems via Standard Neural Network Models'

# %%
sample_title = 'Fully Integrated On-Chip Coil in 0.13 $mu {\rm m}$ CMOS for Wireless Power Transfer Through Biological Media'
sample_title
# Out:
# 'Fully Integrated On-Chip Coil in 0.13 $mu {\rm m}$ CMOS for Wireless Power Transfer Through Biological Media'

# %%
clean_title(sample_title)
# Out:
# 'Fully Integrated On-Chip Coil in 0.13 CMOS for Wireless Power Transfer Through Biological Media'

# %%
sample_title = 'Construction of cyclic DNA codes over the Ring $\x1a_4[u]/langle u^2-1 \rangle $ Based on the deletion distance'
sample_title
# Out:
# 'Construction of cyclic DNA codes over the Ring $\x1a_4[u]/langle u^2-1 \rangle $ Based on the deletion distance'

# %%
clean_title(sample_title)
# Out:
# 'Construction of cyclic DNA codes over the Ring Based on the deletion distance'

# %%
df['clean_title'] = df['title'].progress_apply(lambda x: clean_title(x))
df
# Out:
#   0%|          | 0/4894081 [00:00<?, ?it/s]
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references  \
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
#                                             clean_title
# 0     Characterization of whole-body muscle activity...
# 1     The effect of codebook design on the BER perfo...
# 2     An Optimized Infrared Detection Strategy for D...
# 3             Unsupervised Natural Image Patch Learning
# 4     Age-associated increase in mnemonic strategy u...
# ...                                                 ...
# 9995  A Dynamic Window Neural Network for CCG Supert...
# 9996  Efficient implementation of quantum circuits w...
# 9997  A Dataset for Building Code-Mixed Goal Oriente...
# 9998                   Modal operators and toric ideals
# 9999       A Geometric Perspective on the MSTD Question
#
# [4894081 rows x 10 columns]

# %%
df['n_citation'].value_counts()
# Out:
# 0       1356051
# 1        556543
# 2        391241
# 3        295222
# 4        232290
#          ...
# 4338          1
# 6666          1
# 2716          1
# 2850          1
# 3637          1
# Name: n_citation, Length: 3071, dtype: int64

# %%
df['n_citation'].describe()
# Out:
# count   4894081.00
# mean         16.80
# std         115.82
# min           0.00
# 25%           0.00
# 50%           3.00
# 75%          11.00
# max       48327.00
# Name: n_citation, dtype: float64

# %%
df[df['n_citation'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, authors, n_citation, year, doc_type, publisher, venue, references, clean_title]
# Index: []

# %%
df
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references  \
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
#                                             clean_title
# 0     Characterization of whole-body muscle activity...
# 1     The effect of codebook design on the BER perfo...
# 2     An Optimized Infrared Detection Strategy for D...
# 3             Unsupervised Natural Image Patch Learning
# 4     Age-associated increase in mnemonic strategy u...
# ...                                                 ...
# 9995  A Dynamic Window Neural Network for CCG Supert...
# 9996  Efficient implementation of quantum circuits w...
# 9997  A Dataset for Building Code-Mixed Goal Oriente...
# 9998                   Modal operators and toric ideals
# 9999       A Geometric Perspective on the MSTD Question
#
# [4894081 rows x 10 columns]

# %%
df = df[['id', 'clean_title', 'authors', 'n_citation', 'year', 'doc_type', 'publisher', 'venue', 'references']]
df
# Out:
#               id                                        clean_title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
# [4894081 rows x 9 columns]

# %%
df.rename(columns={'clean_title': 'title'}, inplace=True)
df
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
# [4894081 rows x 9 columns]

# %% [markdown]
# # Preprocessing

# %%
df[df['venue'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, authors, n_citation, year, doc_type, publisher, venue, references]
# Index: []

# %%
# Check 'doc_type'

df['doc_type'].value_counts()
# Out:
# Conference     2245013
# Journal        1919348
#                 499441
# Repository      214762
# Book             12823
# BookChapter       1614
# Patent            1062
# Dataset             18
# Name: doc_type, dtype: int64

# %%
# Check 'venue' sample

df['venue'].iloc[0]
# Out:
# {'raw': 'Hellenic Conference on Artificial Intelligence',
#  'id': 1124396182,
#  'type': 'C'}

# %%
# Create utility function to extract venue id and name

def extract_venue_id(data):
    """
    Extract venue id
    """
    venue_id = ""
    
    if data:
        
        if 'id' in data:
            venue_id = data["id"]
    
    return venue_id

def extract_venue_string(data):
    """
    Extract venue string
    """
    venue_str = ""
    
    if data:
        
        if 'raw' in data:
            venue_str = data["raw"]
    
    return venue_str

# %%
extract_venue_id(df['venue'].iloc[0])
# Out:
# 1124396182

# %%
extract_venue_string(df['venue'].iloc[0])
# Out:
# 'Hellenic Conference on Artificial Intelligence'

# %%
df['venue_id'] = df['venue'].progress_apply(lambda x: extract_venue_id(x))
df
# Out:
#   0%|          | 0/4894081 [00:00<?, ?it/s]
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references    venue_id
# 0     [1973012362, 1975079024, 2008605701, 206338057...  1124396182
# 1     [2008104692, 2042519026, 2054692642, 211076718...  2735422400
# 2                                          [2793612255]  2485537415
# 3                  [2078790577, 2550791380, 2950187998]  2597175965
# 4                  [2049056222, 2101135654, 2783148479]   103225281
# ...                                                 ...         ...
# 9995                                                     1184914352
# 9996                                       [2401457073]    41034432
# 9997                                                     1169674987
# 9998                                       [2610670723]    47057106
# 9999               [2064158683, 2134800424, 2744829829]   103671469
#
# [4894081 rows x 10 columns]

# %%
df['venue_str'] = df['venue'].progress_apply(lambda x: extract_venue_string(x))
df
# Out:
#   0%|          | 0/4894081 [00:00<?, ?it/s]
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references    venue_id  \
# 0     [1973012362, 1975079024, 2008605701, 206338057...  1124396182
# 1     [2008104692, 2042519026, 2054692642, 211076718...  2735422400
# 2                                          [2793612255]  2485537415
# 3                  [2078790577, 2550791380, 2950187998]  2597175965
# 4                  [2049056222, 2101135654, 2783148479]   103225281
# ...                                                 ...         ...
# 9995                                                     1184914352
# 9996                                       [2401457073]    41034432
# 9997                                                     1169674987
# 9998                                       [2610670723]    47057106
# 9999               [2064158683, 2134800424, 2744829829]   103671469
#
#                                               venue_str
# 0        Hellenic Conference on Artificial Intelligence
# 1     Signal Processing and Communications Applicati...
# 2                                           IEEE Access
# 3        arXiv: Computer Vision and Pattern Recognition
# 4                                            NeuroImage
# ...                                                 ...
# 9995     National Conference on Artificial Intelligence
# 9996                  Quantum Information & Computation
# 9997  International Conference on Computational Ling...
# 9998                   Journal of Logic and Computation
# 9999                Discrete and Computational Geometry
#
# [4894081 rows x 11 columns]

# %%
# Check sample authors from dataset

df['authors'].iloc[0]
# Out:
# [{'name': 'Ioannis Delis',
#   'org': 'Department of Biomedical Sciences, University of Leeds, Leeds, UK',
#   'id': 1898054021},
#  {'name': 'Pauline Hilt',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 2645550909},
#  {'name': 'Thierry Pozzo',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 531415370},
#  {'name': 'Stefano Panzeri',
#   'org': 'Neural Computation Laboratory, Center for Neuroscience and Cognitive Systems@UniTn, Istituto Italiano di Tecnologia, Rovereto (TN), Italy',
#   'id': 322723101},
#  {'name': 'Bastien Berret',
#   'org': 'Univ. Paris-Sud, Université Paris-Saclay, Orsay Cedex, France',
#   'id': 79947125}]

# %%
# How many unique authors are in the original dataset?

authors_lst = df['authors'].tolist()
len(authors_lst)
# Out:
# 4894081

# %%
[
    author['id'] for author in tqdm(authors_lst[0])
]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [1898054021, 2645550909, 531415370, 322723101, 79947125]

# %%
authors_lst[:2]
# Out:
# [[{'name': 'Ioannis Delis',
#    'org': 'Department of Biomedical Sciences, University of Leeds, Leeds, UK',
#    'id': 1898054021},
#   {'name': 'Pauline Hilt',
#    'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#    'id': 2645550909},
#   {'name': 'Thierry Pozzo',
#    'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#    'id': 531415370},
#   {'name': 'Stefano Panzeri',
#    'org': 'Neural Computation Laboratory, Center for Neuroscience and Cognitive Systems@UniTn, Istituto Italiano di Tecnologia, Rovereto (TN), Italy',
#    'id': 322723101},
#   {'name': 'Bastien Berret',
#    'org': 'Univ. Paris-Sud, Université Paris-Saclay, Orsay Cedex, France',
#    'id': 79947125}],
#  [{'name': 'Ferdi Tekce',
#    'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#    'id': 2865315720},
#   {'name': 'Evren Catak',
#    'org': 'İTÜNOVA Teknoloji A.Ş., Manbul, Türkiye',
#    'id': 2312549210},
#   {'name': 'Umut Engin Ayten',
#    'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#    'id': 2033699703},
#   {'name': 'Lutfiye Durak-Ata',
#    'org': 'Bilişim Enstitüsü, Bilişim Uygulamaları Bölümü, İstanbul Teknik Üniversitesi, Manbul, Türkiye',
#    'id': 2134904855}]]

# %%
[
    [author['id'] for author in authors] for authors in authors_lst[:2]
]
# Out:
# [[1898054021, 2645550909, 531415370, 322723101, 79947125],
#  [2865315720, 2312549210, 2033699703, 2134904855]]

# %%
author_ids_lst = [
    [author['id'] for author in authors] for authors in tqdm(authors_lst)
]
author_ids_lst[:3]
# Out:
#   0%|          | 0/4894081 [00:00<?, ?it/s]
# [[1898054021, 2645550909, 531415370, 322723101, 79947125],
#  [2865315720, 2312549210, 2033699703, 2134904855],
#  [2903536698, 2097180593, 2756219407, 2814008799]]

# %%
author_ids = [author_id for sublist in author_ids_lst for author_id in sublist]
author_ids[:20]
# Out:
# [1898054021,
#  2645550909,
#  531415370,
#  322723101,
#  79947125,
#  2865315720,
#  2312549210,
#  2033699703,
#  2134904855,
#  2903536698,
#  2097180593,
#  2756219407,
#  2814008799,
#  2230089554,
#  564112320,
#  2104333588,
#  9988965,
#  2581165408,
#  2811603551,
#  2856558135]

# %%
unique_author_ids = list(set(author_ids))
len(unique_author_ids)
# Out:
# 4398138

# %% [raw]
# There are 4398138 unique authors based on total number of unique author ids

# %%
unique_author_ids[:10]
# Out:
# [2810183681,
#  2407530497,
#  2231369732,
#  2709520392,
#  41943048,
#  2013265928,
#  2105540619,
#  2248146956,
#  2432696333,
#  2818572301]

# %%
author_name_lst = [
    [author['name'] for author in authors] for authors in tqdm(authors_lst)
]
author_name_lst[:3]
# Out:
#   0%|          | 0/4894081 [00:00<?, ?it/s]
# [['Ioannis Delis',
#   'Pauline Hilt',
#   'Thierry Pozzo',
#   'Stefano Panzeri',
#   'Bastien Berret'],
#  ['Ferdi Tekce', 'Evren Catak', 'Umut Engin Ayten', 'Lutfiye Durak-Ata'],
#  ['Li Cheng', 'Ruijin Liao', 'Lijun Yang', 'Fuzeng Zhang']]

# %%
author_names = [author_name for sublist in author_name_lst for author_name in sublist]
author_names[:20]
# Out:
# ['Ioannis Delis',
#  'Pauline Hilt',
#  'Thierry Pozzo',
#  'Stefano Panzeri',
#  'Bastien Berret',
#  'Ferdi Tekce',
#  'Evren Catak',
#  'Umut Engin Ayten',
#  'Lutfiye Durak-Ata',
#  'Li Cheng',
#  'Ruijin Liao',
#  'Lijun Yang',
#  'Fuzeng Zhang',
#  'Dov Danon',
#  'Hadar Averbuch-Elor',
#  'Ohad Fried',
#  'Daniel Cohen-Or',
#  'Qijing Yu',
#  'Dana M. McCall',
#  'Roya Homayouni']

# %%
unique_author_names = list(set(author_names))
len(unique_author_names)
# Out:
# 3290430

# %% [raw]
# There are 4398138 unique authors based on total number of unique author ids and 3290430 unique authors based on total number of unique author name strings
#
# We will use the id as indicator for total number of unique authors in the dataset.

# %%
authors_lst[:2]
# Out:
# [[{'name': 'Ioannis Delis',
#    'org': 'Department of Biomedical Sciences, University of Leeds, Leeds, UK',
#    'id': 1898054021},
#   {'name': 'Pauline Hilt',
#    'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#    'id': 2645550909},
#   {'name': 'Thierry Pozzo',
#    'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#    'id': 531415370},
#   {'name': 'Stefano Panzeri',
#    'org': 'Neural Computation Laboratory, Center for Neuroscience and Cognitive Systems@UniTn, Istituto Italiano di Tecnologia, Rovereto (TN), Italy',
#    'id': 322723101},
#   {'name': 'Bastien Berret',
#    'org': 'Univ. Paris-Sud, Université Paris-Saclay, Orsay Cedex, France',
#    'id': 79947125}],
#  [{'name': 'Ferdi Tekce',
#    'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#    'id': 2865315720},
#   {'name': 'Evren Catak',
#    'org': 'İTÜNOVA Teknoloji A.Ş., Manbul, Türkiye',
#    'id': 2312549210},
#   {'name': 'Umut Engin Ayten',
#    'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#    'id': 2033699703},
#   {'name': 'Lutfiye Durak-Ata',
#    'org': 'Bilişim Enstitüsü, Bilişim Uygulamaları Bölümü, İstanbul Teknik Üniversitesi, Manbul, Türkiye',
#    'id': 2134904855}]]

# %%
[
    authors for sublist in authors_lst[:10] for authors in sublist
]
# Out:
# [{'name': 'Ioannis Delis',
#   'org': 'Department of Biomedical Sciences, University of Leeds, Leeds, UK',
#   'id': 1898054021},
#  {'name': 'Pauline Hilt',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 2645550909},
#  {'name': 'Thierry Pozzo',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 531415370},
#  {'name': 'Stefano Panzeri',
#   'org': 'Neural Computation Laboratory, Center for Neuroscience and Cognitive Systems@UniTn, Istituto Italiano di Tecnologia, Rovereto (TN), Italy',
#   'id': 322723101},
#  {'name': 'Bastien Berret',
#   'org': 'Univ. Paris-Sud, Université Paris-Saclay, Orsay Cedex, France',
#   'id': 79947125},
#  {'name': 'Ferdi Tekce',
#   'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#   'id': 2865315720},
#  {'name': 'Evren Catak',
#   'org': 'İTÜNOVA Teknoloji A.Ş., Manbul, Türkiye',
#   'id': 2312549210},
#  {'name': 'Umut Engin Ayten',
#   'org': 'Elektronik ve Haberleşme Mühendisliği, Bölümü Yildiz Teknik Üniversitesi, İstanbul/Türkiye',
#   'id': 2033699703},
#  {'name': 'Lutfiye Durak-Ata',
#   'org': 'Bilişim Enstitüsü, Bilişim Uygulamaları Bölümü, İstanbul Teknik Üniversitesi, Manbul, Türkiye',
#   'id': 2134904855},
#  {'name': 'Li Cheng',
#   'org': 'School of Electrical Engineering, Chongqing University, Chongqing, China#TAB#',
#   'id': 2903536698},
#  {'name': 'Ruijin Liao',
#   'org': 'School of Electrical Engineering, Chongqing University, Chongqing, China#TAB#',
#   'id': 2097180593},
#  {'name': 'Lijun Yang',
#   'org': 'School of Electrical Engineering, Chongqing University, Chongqing, China#TAB#',
#   'id': 2756219407},
#  {'name': 'Fuzeng Zhang',
#   'org': 'China Southern Power Grid Co., Ltd. Guangzhou China',
#   'id': 2814008799},
#  {'name': 'Dov Danon', 'id': 2230089554},
#  {'name': 'Hadar Averbuch-Elor', 'id': 564112320},
#  {'name': 'Ohad Fried', 'id': 2104333588},
#  {'name': 'Daniel Cohen-Or', 'id': 9988965},
#  {'name': 'Qijing Yu',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2581165408},
#  {'name': 'Dana M. McCall',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2811603551},
#  {'name': 'Roya Homayouni',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2856558135},
#  {'name': 'Lingfei Tang',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2715743601},
#  {'name': 'Zhijian Chen',
#   'org': 'Institute of Gerontology, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2555934509},
#  {'name': 'Daniel Schoff',
#   'org': 'Institute of Gerontology, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2858247946},
#  {'name': 'Mayu Nishimura',
#   'org': 'Psychology, Neuroscience and Behaviour, McMaster University, Hamilton, ON, L8S 4K1, Canada',
#   'id': 2937623039},
#  {'name': 'Sarah Raz',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 2309861872},
#  {'name': 'Noa Ofen',
#   'org': 'Psychology Department, Wayne State University, Detroit, MI, 48202, USA',
#   'id': 273927964},
#  {'name': 'Ester Gonzalez-Sosa', 'id': 2072577535},
#  {'name': 'Ruben Vera-Rodriguez', 'id': 1922578931},
#  {'name': 'Julian Fierrez', 'id': 120405888},
#  {'name': 'Vishal M. Patel', 'id': 2118029367},
#  {'name': 'Fangneng Zhan',
#   'org': 'Nanyang Technological University',
#   'id': 2823584315},
#  {'name': 'Shijian Lu',
#   'org': 'Nanyang Technological University',
#   'id': 2130315075},
#  {'name': 'Chuhui Xue',
#   'org': 'Nanyang Technological University',
#   'id': 2851501337},
#  {'name': 'Mohammad Wardat',
#   'org': 'Iowa State University, IA, USA',
#   'id': 2064483243},
#  {'name': 'Mahmoud Al-Ayyoub',
#   'org': 'Jordan University of Science and Technology, Irbid-Jordan,',
#   'id': 2225947635},
#  {'name': 'Yaser Jararweh',
#   'org': 'Jordan University of Science and Technology, Irbid-Jordan,',
#   'id': 9812142},
#  {'name': 'Abdallah A. Khreishah',
#   'org': 'New Jersey Institute of Technology, NJ, USA',
#   'id': 2032803358},
#  {'name': 'Jia Zhao',
#   'org': 'Simon Fraser University, Burnaby, Canada',
#   'id': 2734474261},
#  {'name': 'Wei Gong',
#   'org': 'University of Science and Technology of China, China, Simon Fraser University, Canada',
#   'id': 2197590639},
#  {'name': 'Jiangchuan Liu',
#   'org': 'Simon Fraser University, Burnaby, Canada',
#   'id': 2099242182},
#  {'name': 'Peijun Sang',
#   'org': 'Department of Statistics and Actuarial Science, Simon Fraser University, Burnaby, BC, Canada V5A1S6',
#   'id': 2813323485},
#  {'name': 'Richard A. Lockhart',
#   'org': 'Department of Statistics and Actuarial Science, Simon Fraser University, Burnaby, BC, Canada V5A1S6',
#   'id': 2171980649},
#  {'name': 'Jiguo Cao',
#   'org': 'Department of Statistics and Actuarial Science, Simon Fraser University, Burnaby, BC, Canada V5A1S6',
#   'id': 2132412357}]

# %%
authors = [
    author for sublist in authors_lst for author in sublist
]
len(authors)
# Out:
# 14934850

# %%
authors[:3]
# Out:
# [{'name': 'Ioannis Delis',
#   'org': 'Department of Biomedical Sciences, University of Leeds, Leeds, UK',
#   'id': 1898054021},
#  {'name': 'Pauline Hilt',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 2645550909},
#  {'name': 'Thierry Pozzo',
#   'org': 'Fondazione Istituto Italiano di Tecnologia, Centro di Neurofisiologia traslazionale c/o sezione Fisiologia Umana, Ferrara, Italy',
#   'id': 531415370}]

# %%
author_df = pd.DataFrame(authors)
author_df
# Out:
#                       name                                                org  \
# 0            Ioannis Delis  Department of Biomedical Sciences, University ...
# 1             Pauline Hilt  Fondazione Istituto Italiano di Tecnologia, Ce...
# 2            Thierry Pozzo  Fondazione Istituto Italiano di Tecnologia, Ce...
# 3          Stefano Panzeri  Neural Computation Laboratory, Center for Neur...
# 4           Bastien Berret  Univ. Paris-Sud, Université Paris-Saclay, Orsa...
# ...                    ...                                                ...
# 14934845  Riccardo Camerlo  Dipartimento di Matematica, Università di Geno...
# 14934846  Giovanni Pistone  de Castro Statistics, Collegio Carlo Alberto, ...
# 14934847     Fabio Rapallo  Dipartimento di Scienze e Innovazione Tecnolog...
# 14934848  Steven J. Miller  Department of Mathematics & Statistics, Willia...
# 14934849  Carsten Peterson  Department of Mathematics, University of Michi...
#
#                   id
# 0         1898054021
# 1         2645550909
# 2          531415370
# 3          322723101
# 4           79947125
# ...              ...
# 14934845  1046033706
# 14934846  2028717393
# 14934847    47534353
# 14934848  2137280055
# 14934849  2698239273
#
# [14934850 rows x 3 columns]

# %%
# Re-order column names

author_df = author_df[['id', 'name', 'org']]
author_df
# Out:
#                   id              name  \
# 0         1898054021     Ioannis Delis
# 1         2645550909      Pauline Hilt
# 2          531415370     Thierry Pozzo
# 3          322723101   Stefano Panzeri
# 4           79947125    Bastien Berret
# ...              ...               ...
# 14934845  1046033706  Riccardo Camerlo
# 14934846  2028717393  Giovanni Pistone
# 14934847    47534353     Fabio Rapallo
# 14934848  2137280055  Steven J. Miller
# 14934849  2698239273  Carsten Peterson
#
#                                                         org
# 0         Department of Biomedical Sciences, University ...
# 1         Fondazione Istituto Italiano di Tecnologia, Ce...
# 2         Fondazione Istituto Italiano di Tecnologia, Ce...
# 3         Neural Computation Laboratory, Center for Neur...
# 4         Univ. Paris-Sud, Université Paris-Saclay, Orsa...
# ...                                                     ...
# 14934845  Dipartimento di Matematica, Università di Geno...
# 14934846  de Castro Statistics, Collegio Carlo Alberto, ...
# 14934847  Dipartimento di Scienze e Innovazione Tecnolog...
# 14934848  Department of Mathematics & Statistics, Willia...
# 14934849  Department of Mathematics, University of Michi...
#
# [14934850 rows x 3 columns]

# %%
len(unique_author_ids)
# Out:
# 4398138

# %%
author_df.drop_duplicates(subset=['id'], keep='first')
# Out:
#                   id              name  \
# 0         1898054021     Ioannis Delis
# 1         2645550909      Pauline Hilt
# 2          531415370     Thierry Pozzo
# 3          322723101   Stefano Panzeri
# 4           79947125    Bastien Berret
# ...              ...               ...
# 14934729  2962813519      Je-Kwang Ryu
# 14934753  2964296278       Boyuan Kong
# 14934805  2963126023      Fahem Kebair
# 14934827  2473832003   Asmaa H. Elsaid
# 14934830  2771890869  Sankar Mukherjee
#
#                                                         org
# 0         Department of Biomedical Sciences, University ...
# 1         Fondazione Istituto Italiano di Tecnologia, Ce...
# 2         Fondazione Istituto Italiano di Tecnologia, Ce...
# 3         Neural Computation Laboratory, Center for Neur...
# 4         Univ. Paris-Sud, Université Paris-Saclay, Orsa...
# ...                                                     ...
# 14934729                                                NaN
# 14934753  Dept. of Electrical Engineering and Computer S...
# 14934805                                                NaN
# 14934827  Information Systems Department, Faculty of Com...
# 14934830  Dept. of Computer Science & Engineering, India...
#
# [4398138 rows x 3 columns]

# %%
# Remove duplicates

author_df = author_df.drop_duplicates(subset=['id'], keep='first')
author_df
# Out:
#                   id              name  \
# 0         1898054021     Ioannis Delis
# 1         2645550909      Pauline Hilt
# 2          531415370     Thierry Pozzo
# 3          322723101   Stefano Panzeri
# 4           79947125    Bastien Berret
# ...              ...               ...
# 14934729  2962813519      Je-Kwang Ryu
# 14934753  2964296278       Boyuan Kong
# 14934805  2963126023      Fahem Kebair
# 14934827  2473832003   Asmaa H. Elsaid
# 14934830  2771890869  Sankar Mukherjee
#
#                                                         org
# 0         Department of Biomedical Sciences, University ...
# 1         Fondazione Istituto Italiano di Tecnologia, Ce...
# 2         Fondazione Istituto Italiano di Tecnologia, Ce...
# 3         Neural Computation Laboratory, Center for Neur...
# 4         Univ. Paris-Sud, Université Paris-Saclay, Orsa...
# ...                                                     ...
# 14934729                                                NaN
# 14934753  Dept. of Electrical Engineering and Computer S...
# 14934805                                                NaN
# 14934827  Information Systems Department, Faculty of Com...
# 14934830  Dept. of Computer Science & Engineering, India...
#
# [4398138 rows x 3 columns]

# %%
author_df.fillna("", inplace=True)
author_df
# Out:
#                   id              name  \
# 0         1898054021     Ioannis Delis
# 1         2645550909      Pauline Hilt
# 2          531415370     Thierry Pozzo
# 3          322723101   Stefano Panzeri
# 4           79947125    Bastien Berret
# ...              ...               ...
# 14934729  2962813519      Je-Kwang Ryu
# 14934753  2964296278       Boyuan Kong
# 14934805  2963126023      Fahem Kebair
# 14934827  2473832003   Asmaa H. Elsaid
# 14934830  2771890869  Sankar Mukherjee
#
#                                                         org
# 0         Department of Biomedical Sciences, University ...
# 1         Fondazione Istituto Italiano di Tecnologia, Ce...
# 2         Fondazione Istituto Italiano di Tecnologia, Ce...
# 3         Neural Computation Laboratory, Center for Neur...
# 4         Univ. Paris-Sud, Université Paris-Saclay, Orsa...
# ...                                                     ...
# 14934729
# 14934753  Dept. of Electrical Engineering and Computer S...
# 14934805
# 14934827  Information Systems Department, Faculty of Com...
# 14934830  Dept. of Computer Science & Engineering, India...
#
# [4398138 rows x 3 columns]

# %%
author_df.to_csv('data/dblp/author.csv', index=False)

# %%
df
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#                                                   venue  \
# 0     {'raw': 'Hellenic Conference on Artificial Int...
# 1     {'raw': 'Signal Processing and Communications ...
# 2     {'raw': 'IEEE Access', 'id': 2485537415, 'type...
# 3     {'raw': 'arXiv: Computer Vision and Pattern Re...
# 4     {'raw': 'NeuroImage', 'id': 103225281, 'type':...
# ...                                                 ...
# 9995  {'raw': 'National Conference on Artificial Int...
# 9996  {'raw': 'Quantum Information & Computation', '...
# 9997  {'raw': 'International Conference on Computati...
# 9998  {'raw': 'Journal of Logic and Computation', 'i...
# 9999  {'raw': 'Discrete and Computational Geometry',...
#
#                                              references    venue_id  \
# 0     [1973012362, 1975079024, 2008605701, 206338057...  1124396182
# 1     [2008104692, 2042519026, 2054692642, 211076718...  2735422400
# 2                                          [2793612255]  2485537415
# 3                  [2078790577, 2550791380, 2950187998]  2597175965
# 4                  [2049056222, 2101135654, 2783148479]   103225281
# ...                                                 ...         ...
# 9995                                                     1184914352
# 9996                                       [2401457073]    41034432
# 9997                                                     1169674987
# 9998                                       [2610670723]    47057106
# 9999               [2064158683, 2134800424, 2744829829]   103671469
#
#                                               venue_str
# 0        Hellenic Conference on Artificial Intelligence
# 1     Signal Processing and Communications Applicati...
# 2                                           IEEE Access
# 3        arXiv: Computer Vision and Pattern Recognition
# 4                                            NeuroImage
# ...                                                 ...
# 9995     National Conference on Artificial Intelligence
# 9996                  Quantum Information & Computation
# 9997  International Conference on Computational Ling...
# 9998                   Journal of Logic and Computation
# 9999                Discrete and Computational Geometry
#
# [4894081 rows x 11 columns]

# %%
# Keep relevant columns

df = df[['id', 'title', 'authors', 'n_citation', 'year', 'doc_type', 'publisher', 'venue_id', 'venue_str', 'references']]
df
# Out:
#               id                                              title  \
# 0     2873507692  Characterization of whole-body muscle activity...
# 1     2873533962  The effect of codebook design on the BER perfo...
# 2     2873535434  An Optimized Infrared Detection Strategy for D...
# 3     2873541924          Unsupervised Natural Image Patch Learning
# 4     2873550248  Age-associated increase in mnemonic strategy u...
# ...          ...                                                ...
# 9995  2963831124  A Dynamic Window Neural Network for CCG Supert...
# 9996  2963831130  Efficient implementation of quantum circuits w...
# 9997  2963831170  A Dataset for Building Code-Mixed Goal Oriente...
# 9998  2963831230                   Modal operators and toric ideals
# 9999  2963831250       A Geometric Perspective on the MSTD Question
#
#                                                 authors  n_citation  year  \
# 0     [{'name': 'Ioannis Delis', 'org': 'Department ...           0  2018
# 1     [{'name': 'Ferdi Tekce', 'org': 'Elektronik ve...           0  2018
# 2     [{'name': 'Li Cheng', 'org': 'School of Electr...           0  2018
# 3     [{'name': 'Dov Danon', 'id': 2230089554}, {'na...           0  2018
# 4     [{'name': 'Qijing Yu', 'org': 'Psychology Depa...           2  2018
# ...                                                 ...         ...   ...
# 9995  [{'name': 'Huijia Wu', 'id': 2531734576}, {'na...           0  2016
# 9996  [{'name': 'Stephen Brierley', 'org': 'DAMTP, C...           3  2017
# 9997  [{'name': 'Suman Banerjee', 'id': 2808453915},...           0  2018
# 9998  [{'name': 'Riccardo Camerlo', 'org': 'Dipartim...           0  2019
# 9999  [{'name': 'Steven J. Miller', 'org': 'Departme...           0  2019
#
#         doc_type                                          publisher  \
# 0     Conference                                                ACM
# 1     Conference                                               IEEE
# 2        Journal  Institute of Electrical and Electronics Engine...
# 3     Repository
# 4        Journal                                     Academic Press
# ...          ...                                                ...
# 9995  Conference
# 9996     Journal                         Rinton Press, Incorporated
# 9997  Conference
# 9998     Journal                      Oxford University Press (OUP)
# 9999     Journal            Springer Science and Business Media LLC
#
#         venue_id                                          venue_str  \
# 0     1124396182     Hellenic Conference on Artificial Intelligence
# 1     2735422400  Signal Processing and Communications Applicati...
# 2     2485537415                                        IEEE Access
# 3     2597175965     arXiv: Computer Vision and Pattern Recognition
# 4      103225281                                         NeuroImage
# ...          ...                                                ...
# 9995  1184914352     National Conference on Artificial Intelligence
# 9996    41034432                  Quantum Information & Computation
# 9997  1169674987  International Conference on Computational Ling...
# 9998    47057106                   Journal of Logic and Computation
# 9999   103671469                Discrete and Computational Geometry
#
#                                              references
# 0     [1973012362, 1975079024, 2008605701, 206338057...
# 1     [2008104692, 2042519026, 2054692642, 211076718...
# 2                                          [2793612255]
# 3                  [2078790577, 2550791380, 2950187998]
# 4                  [2049056222, 2101135654, 2783148479]
# ...                                                 ...
# 9995
# 9996                                       [2401457073]
# 9997
# 9998                                       [2610670723]
# 9999               [2064158683, 2134800424, 2744829829]
#
# [4894081 rows x 10 columns]

# %%
df.to_csv('data/dblp/data.csv', index=False)
